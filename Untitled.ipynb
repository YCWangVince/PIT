# %%
import matplotlib.pyplot as plt
from model.dataset import pinn_dataset

# %%
# !pip install ghalton
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.5/321.5 kB 11.4 MB/s eta 0:00:00
# ...
